# %%
# %%html
# <style>.container { width:75% !important; }</style>
# <link rel='stylesheet' type='text/css' href='https://cdn.kastatic.org/genfiles/stylesheets/en/mobile-package-5669d8.css'>
# <link rel='stylesheet' type='text/css' href='https://cdn.kastatic.org/genfiles/stylesheets/en/homepage-package-fba845.css'>
# <body>
#   <article id="homepage">
#     <a id="library-section"></a>
#     <div class="library-section">
#       <div class="section-separator library-section-separator">
#         <h2><span class="section-separator-text">Nipype Tutorial</span></h2><hr/>
#         <p>Welcome to the Nipype Tutorial! This tutorial will teach you all essentials about Nipype so that you go from
#             beginner to expert in no time. The tutorial will try to cover the most common concepts and use cases, but for
#             everything that isn't covered here, check out the main homepage under
#             <a href="http://nipype.readthedocs.io/en/latest/">nipype.readthedocs.io</a>. This tutorial is completly web based.
#             This means that you don't have to install anything on your system to run it. It all runs on
#             <a href="http://mybinder.org/">http://mybinder.org/</a>. This online environment provides next to Nipype the most
#             common and necessary python packages, including dipy, matplotlib, nibabel, nipy, numpy, pandas, scikit-image,
#             scikit-learn, scipy, seaborn. Additionally, it also provides a full functioning FSL and AFNI. But remember, this
#             all runs on a web server, so don't expect enorme computiational power and don't overcharge the server. This
#             environment should only be used for tutorial reasons. And thanks again to the
#             <a href="http://mybinder.org/">mybinder.org team</a> for providing this cool service.</p>
#       </div>
#
#       <!--to change the color of the title or section, change the second h2 class argument
#        and the third div argument to either science, computing, humanities, test-prep or
#        economics-finance-domain-->
#
#       <!--to change the number of rows per column, change the last number in 'pure-u-1-3'.
#        For example, to have three columns, change the value to 'pure-u-1-3'-->
#
#       <h2 class="domain-header economics-finance-domain"><a class="domain-title">Overview</a></h2>
#       <div class="pure-g domain-table-container economics-finance-domain">
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/overview_nipype.ipynb">Nipype</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/overview_jupyter-notebook.ipynb">Jupyter-Notebook</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/overview_python.ipynb">Python</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/overview_dataset.ipynb">Tutorial Dataset</a>
#       </div>
#       <p>This section is meant as a general overview. It should give you a general short introduction to the main topics that
#           you need to understand to use Nipype and this tutorial.</p>
#
#       <h2 class="domain-header humanities"><a class="domain-title">Basic Concepts</a></h2>
#       <div class="pure-g domain-table-container humanities">
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/basic_nodes.ipynb">Nodes</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Workflow</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Interfaces</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Iteration</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Graph Visualization</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Plugins</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Run Workflow</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Crash Files</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Installation</a>
#       </div>
#       <p>This section will introduce you to all the main keyplayers in Nipype. Basic concepts that you need to understand to
#           full understand and appreciate Nipype. Once you understand this section, you will know all that you need to know
#           to create any kind of Nipype workflow.</p>
#
#       <h2 class="domain-header computing"><a class="domain-title">Advanced Applications</a></h2>
#       <div class="pure-g domain-table-container computing">
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Commandline</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Topic 2</a>
#       </div>
#       <p>Some explanation about section 3</p>
#
#       <h2 class="domain-header math"><a class="domain-title">Useful Resources</a></h2>
#       <div class="pure-g domain-table-container math">
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Questions and Answers</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Usefull Resources</a>
#       </div>
#       <p>Some explanation about section 4</p>
#
#       <h2 class="domain-header test-prep"><a class="domain-title">Development</a></h2>
#       <div class="pure-g domain-table-container test-prep">
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Topic 1</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Topic 2</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Topic 3</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Topic 4</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="somenotebook.ipynb">Topic 5</a>
#       </div>
#       <p>Some explanation about section 5</p>
#
#     </div>
#   </article>
# </body>
#
# <!--The following code will cause the code cell to disappear-->
#
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <hr/>
#
# If you want to accesse this notebooks tree structure, click the following button: <form action="../tree" target="_blank"><input type="submit" value="Go to Notebook Tree"></form>
# <p></p>
#
# The layout of this document was adapted from <a href="www.khanacademy.org/library">https://www.khanacademy.org/library</a>. To inspect the embedded html code click the following button:
# <form action="javascript:code_toggle()"><input type="submit" value="Show HTML code"></form>
# Out:
# <style>.container { width:75% !important; }</style>
# <link rel='stylesheet' type='text/css' href='https://cdn.kastatic.org/genfiles/stylesheets/en/mobile-package-5669d8.css'>
# <link rel='stylesheet' type='text/css' href='https://cdn.kastatic.org/genfiles/stylesheets/en/homepage-package-fba845.css'>
# <body>
#   <article id="homepage">
#     <a id="library-section"></a>
#     <div class="library-section">
#       <div class="section-separator library-section-separator">
#         <h2><span class="section-separator-text">Nipype Tutorial</span></h2><hr/>
#         <p>Welcome to the Nipype Tutorial! This tutorial will teach you all essentials about Nipype so that you go from
#             beginner to expert in no time. The tutorial will try to cover the most common concepts and use cases, but for
#             everything that isn't covered here, check out the main homepage under
# ...
